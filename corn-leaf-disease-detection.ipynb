# %% [markdown]
# ## <center>Corn Leaf Disease Detection</center>

# %% [markdown]
# <center><img src="https://images.unsplash.com/photo-1503788125311-ae8d4da8ab54?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=774&q=80"></center>

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torch import nn
from torch.optim import Adam
from torchvision import models

from sklearn.metrics import classification_report, confusion_matrix

# %%
# !pip install split-folders
# Out:
# Requirement already satisfied: split-folders in c:\users\ashmi\anaconda3\lib\site-packages (0.5.1)

# %%
import splitfolders

# %% [markdown]
# ## Choosing the Device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## Splitting the Data Into Train, Validation and Test Sets

# %% [markdown]
# Because the data is not seperated, it should be splitted into Train, Validation and Test sets. To do that, I used splitfolders library and splitted the data into Train, Validation and Test sets by 70%, 20% and 10% respectively.

# %%
splitfolders.ratio("C:\\Users\\ashmi\\Downloads\\archive (2)\\data",
            output="splitted_data",
            seed=42,
            ratio=(.7, .2, .1),
            group_prefix=None,
            move=False)
# Out:
# Copying files: 4188 files [00:23, 181.08 files/s]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# Resizing and Normalizing methods are applied to all of the datasets but data augmentation techniques are only applied to Train set in order to richen the data so that the model possibly will yield more accurate results.

# %%
#----------------------
train_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.GaussianBlur(kernel_size=(3, 7), sigma=(0.1, 2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

# -------- Transformation for the Whole Dataset for Visualization Purposes --------
data_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
])

# %% [markdown]
# ## Loading the Data

# %%
train = datasets.ImageFolder(root=r"C:\Users\ashmi\cv project\splitted_data\train",
                              transform=train_transform)

val = datasets.ImageFolder(root=r"C:\Users\ashmi\cv project\splitted_data\val",
                              transform=val_transform)

test = datasets.ImageFolder(root=r"C:\Users\ashmi\cv project\splitted_data\test",
                              transform=test_transform)

# -------- Getting the Whole Dataset for Visualization Purposes --------
data = datasets.ImageFolder(root=r"C:\Users\ashmi\Downloads\archive (2)\data",transform=data_transform)

# %%
print("Dataset Labels:\n", train.class_to_idx, "\n")

for name, dataset in zip(["TRAIN", "VALIDATION", "TEST"], [train, val, test]):
    images_per_class = pd.Series(dataset.targets).value_counts()
    print(f"Images per Class in {name}:")
    print(images_per_class, "\n")
# Out:
# Dataset Labels:
#  {'Blight': 0, 'Common_Rust': 1, 'Gray_Leaf_Spot': 2, 'Healthy': 3}
#
# Images per Class in TRAIN:
# 1    914
# 3    813
# 0    802
# 2    401
# dtype: int64
#
# Images per Class in VALIDATION:
# 1    261
# 3    232
# 0    229
# 2    114
# dtype: int64
#
# Images per Class in TEST:
# 1    131
# 3    117
# 0    115
# 2     59
# dtype: int64

# %% [markdown]
# #### Plotting a few Images

# %% [markdown]
# Images plotted below did not undergo a data augmentation process. Therefore, they seem to be normal.

# %%
labels_for_viz = {v: k for k, v in data.class_to_idx.items()}

fig, ax = plt.subplots(3, 5, figsize=(15, 10))
ax = ax.flatten()
for i in range(15):
    sample = random.randint(0, len(data))
    ax[i].imshow(data[sample][0].permute(1, 2, 0))
    ax[i].title.set_text(labels_for_viz[data[sample][1]])

# %% [markdown]
# ### Plotting the Augmented Images

# %% [markdown]
# Because data augmentation methods are applied to Train set, it can be seen that images are blurred, horizontally and vertically flipped compared to the unaugmented images.

# %%
fig, ax = plt.subplots(3, 5, figsize=(15, 10))
ax = ax.flatten()
for i in range(15):
    sample = random.randint(0, len(train))
    ax[i].imshow(train[sample][0].permute(1, 2, 0))
    ax[i].title.set_text(labels_for_viz[train[sample][1]])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Before passing the data in a neural network, it should be batched and shuffled. Since test will not be used in training process, there is no need to shuffle it.

# %%
train_dataloader = DataLoader(dataset=train,
                             batch_size=32,
                             num_workers=2,
                             shuffle=True)

val_dataloader = DataLoader(dataset=val,
                             batch_size=32,
                             num_workers=2,
                             shuffle=True)

test_dataloader = DataLoader(dataset=test,
                             batch_size=32,
                             num_workers=2,
                             shuffle=False)

# %% [markdown]
# When looking at the order of the data in relevant folder, it can be observed that images from class "Blight" comes first, "Common_Rust" second, "Gray_Leaf_Spot" third and "Healthy" last. An order as such can be problematic for the model to train unbiasedly. Let's take a batch and look at the labels to make sure that the data is shuffled.

# %%
img, label = next(iter(train_dataloader))
print("Batch and Image Shape:", img.shape, "--> [batch_size, color_channels, height, width]")
print("\nLabels:", label)
# Out:
# Batch and Image Shape: torch.Size([32, 3, 256, 256]) --> [batch_size, color_channels, height, width]
#
# Labels: tensor([2, 1, 1, 3, 3, 3, 0, 2, 0, 2, 1, 0, 2, 3, 1, 0, 1, 0, 3, 1, 1, 2, 1, 0,
#         3, 1, 2, 1, 3, 1, 0, 0])

# %% [markdown]
# ## Building the Deep Learning Model

# %% [markdown]
# Custom neural network architecture can be designed for this machine learning problem. With a neural network similar to the one below, an accuracy score around 80-84% is obtained. But for this project, I opt to apply Transfer Learning using ResNet18 architecture.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=131072, out_features=32), # in_features are selected based on the output that Flatten layer yields
            nn.ReLU(),
            nn.Linear(in_features=32, out_features=16),
            nn.ReLU(),
            nn.Linear(in_features=16, out_features=4)
        )
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Transfer Learning - ResNet18

# %% [markdown]
# Transfer learning is a process of utilizing pre-trained machine learning models and applying them to a related task without need of models' learning from scratch for saving time and possibly better performance.

# %%
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(in_features=512, out_features=4)
model = model.to(device)
# Out:
# C:\Users\ashmi\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\ashmi\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %% [markdown]
# ## Defining the Loss Function and Choosing an Optimizer

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=10e-3)

# %% [markdown]
# ## Defining Train and Test Functions

# %%
def train_and_validate_model(num_epochs):
    val_best_accuracy = 0.0
    train_loss_history = []
    val_loss_history = []
    train_accuracy_history = []
    val_accuracy_history = []
    
    print("Training begins...")
    for epoch in range(1, num_epochs+1):
        running_train_loss = 0.0
        running_train_accuracy = 0.0
        train_total = 0
        running_val_accuracy = 0.0
        running_val_loss = 0.0
        val_total = 0
        
        
        # TRAINING LOOP
        for data in train_dataloader:
            inputs, outputs = data
            inputs, outputs = inputs.to(device), outputs.to(device)
            optimizer.zero_grad()
            predictions = model(inputs)
            train_loss = loss_fn(predictions, outputs)
            _, train_predicted = torch.max(predictions, 1)
            running_train_accuracy += (train_predicted == outputs).sum().item()
            train_total += outputs.size(0)
            train_loss.backward()
            optimizer.step()
            running_train_loss += train_loss.item()
            
        train_loss_value = running_train_loss/len(train_dataloader)
        train_loss_history.append(train_loss_value)
        train_accuracy = (100*running_train_accuracy)/train_total
        train_accuracy_history.append(train_accuracy)
        
        # VALIDATION LOOP
        with torch.no_grad():
            model.eval()
            for data in val_dataloader:
                inputs, outputs = data
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                val_loss = loss_fn(predictions, outputs)
                
                _, val_predicted = torch.max(predictions, 1)
                running_val_loss += val_loss.item()
                val_total += outputs.size(0)
                running_val_accuracy += (val_predicted == outputs).sum().item()
                
        val_loss_value = running_val_loss/len(val_dataloader)
        val_loss_history.append(val_loss_value)
        val_accuracy = (100*running_val_accuracy)/val_total
        val_accuracy_history.append(val_accuracy)
        
        if val_accuracy > val_best_accuracy:
            torch.save(model.state_dict(), "model1.pth")
            val_best_accuracy = val_accuracy
        
        print("Completed Epoch: ", epoch, "- Training Accuracy: %d" %train_accuracy, "- Validation Accuracy: %d" %val_accuracy, "- Training Loss: %.4f" %train_loss_value, "- Validation Loss: %.4f" %val_loss_value)
    return train_accuracy_history, val_accuracy_history, train_loss_history, val_loss_history

# %%
def test_model():
    model = models.resnet18(pretrained=True)
    model.fc = nn.Linear(in_features=512, out_features=4)
    model = model.to(device)
    path = "model1F.pth"
    model.load_state_dict(torch.load(path))
    model.eval()
    
    running_accuracy = 0
    total = 0
    all_predictions = []
    
    with torch.no_grad():
        for data in test_dataloader:
            inputs, outputs = data
            inputs, outputs = inputs.to(device), outputs.to(device)
            outputs = outputs.to(torch.float32)
            predictions = model(inputs)
            _, predicted = torch.max(predictions, 1)
            total += outputs.size(0)
            running_accuracy += (predicted == outputs).sum().item()
            accuracy = 100*running_accuracy/total
            
            all_predictions.append(list(predicted.to("cpu").numpy()))
        print("Test Accuracy: ", accuracy)
    return np.hstack(all_predictions) # returns a flattened array of batches of predictions

# %%
EPOCHS = 1000
train_accuracy_history, val_accuracy_history, train_loss_history, val_loss_history = train_and_validate_model(EPOCHS)
print("Training finished...\n")
all_preds = test_model()
# Out:
# Training begins...
# Completed Epoch:  1 - Training Accuracy: 85 - Validation Accuracy: 88 - Training Loss: 0.4075 - Validation Loss: 0.2713
# Completed Epoch:  2 - Training Accuracy: 84 - Validation Accuracy: 93 - Training Loss: 0.3927 - Validation Loss: 0.1951
# Completed Epoch:  3 - Training Accuracy: 91 - Validation Accuracy: 90 - Training Loss: 0.2035 - Validation Loss: 0.2147
# Completed Epoch:  4 - Training Accuracy: 94 - Validation Accuracy: 89 - Training Loss: 0.1432 - Validation Loss: 0.3189
# Completed Epoch:  5 - Training Accuracy: 95 - Validation Accuracy: 94 - Training Loss: 0.1293 - Validation Loss: 0.1525
# Completed Epoch:  6 - Training Accuracy: 96 - Validation Accuracy: 89 - Training Loss: 0.1089 - Validation Loss: 0.2846
# Completed Epoch:  7 - Training Accuracy: 95 - Validation Accuracy: 94 - Training Loss: 0.1169 - Validation Loss: 0.1418
# Completed Epoch:  8 - Training Accuracy: 96 - Validation Accuracy: 95 - Training Loss: 0.0914 - Validation Loss: 0.1148
# Completed Epoch:  9 - Training Accuracy: 97 - Validation Accuracy: 95 - Training Loss: 0.0834 - Validation Loss: 0.1245
# Completed Epoch:  10 - Training Accuracy: 97 - Validation Accuracy: 95 - Training Loss: 0.0750 - Validation Loss: 0.1227
# Completed Epoch:  11 - Training Accuracy: 97 - Validation Accuracy: 93 - Training Loss: 0.0751 - Validation Loss: 0.1369
# Completed Epoch:  12 - Training Accuracy: 97 - Validation Accuracy: 95 - Training Loss: 0.0806 - Validation Loss: 0.1175
# Completed Epoch:  13 - Training Accuracy: 97 - Validation Accuracy: 95 - Training Loss: 0.0760 - Validation Loss: 0.1075
# Completed Epoch:  14 - Training Accuracy: 97 - Validation Accuracy: 95 - Training Loss: 0.0651 - Validation Loss: 0.1411
# Completed Epoch:  15 - Training Accuracy: 97 - Validation Accuracy: 96 - Training Loss: 0.0543 - Validation Loss: 0.1188
# Completed Epoch:  16 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0500 - Validation Loss: 0.1396
# Completed Epoch:  17 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0481 - Validation Loss: 0.1123
# Completed Epoch:  18 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0476 - Validation Loss: 0.1459
# Completed Epoch:  19 - Training Accuracy: 97 - Validation Accuracy: 96 - Training Loss: 0.0654 - Validation Loss: 0.1179
# Completed Epoch:  20 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0342 - Validation Loss: 0.1394
# Completed Epoch:  21 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0309 - Validation Loss: 0.1400
# Completed Epoch:  22 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0195 - Validation Loss: 0.1596
# Completed Epoch:  23 - Training Accuracy: 99 - Validation Accuracy: 97 - Training Loss: 0.0244 - Validation Loss: 0.1193
# Completed Epoch:  24 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0275 - Validation Loss: 0.1350
# Completed Epoch:  25 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0160 - Validation Loss: 0.1494
# Completed Epoch:  26 - Training Accuracy: 87 - Validation Accuracy: 94 - Training Loss: 0.3643 - Validation Loss: 0.1767
# Completed Epoch:  27 - Training Accuracy: 96 - Validation Accuracy: 95 - Training Loss: 0.0856 - Validation Loss: 0.1807
# Completed Epoch:  28 - Training Accuracy: 97 - Validation Accuracy: 94 - Training Loss: 0.0535 - Validation Loss: 0.1636
# Completed Epoch:  29 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0287 - Validation Loss: 0.1298
# Completed Epoch:  30 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0211 - Validation Loss: 0.1400
# Completed Epoch:  31 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0249 - Validation Loss: 0.1247
# Completed Epoch:  32 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0176 - Validation Loss: 0.1445
# Completed Epoch:  33 - Training Accuracy: 98 - Validation Accuracy: 95 - Training Loss: 0.0289 - Validation Loss: 0.1309
# Completed Epoch:  34 - Training Accuracy: 99 - Validation Accuracy: 93 - Training Loss: 0.0117 - Validation Loss: 0.2871
# Completed Epoch:  35 - Training Accuracy: 96 - Validation Accuracy: 94 - Training Loss: 0.1023 - Validation Loss: 0.1766
# Completed Epoch:  36 - Training Accuracy: 98 - Validation Accuracy: 94 - Training Loss: 0.0292 - Validation Loss: 0.1650
# Completed Epoch:  37 - Training Accuracy: 99 - Validation Accuracy: 91 - Training Loss: 0.0147 - Validation Loss: 0.3601
# Completed Epoch:  38 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0166 - Validation Loss: 0.1385
# Completed Epoch:  39 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0084 - Validation Loss: 0.1490
# Completed Epoch:  40 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0122 - Validation Loss: 0.1374
# Completed Epoch:  41 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0065 - Validation Loss: 0.1473
# Completed Epoch:  42 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0051 - Validation Loss: 0.1457
# Completed Epoch:  43 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0028 - Validation Loss: 0.1556
# Completed Epoch:  44 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0038 - Validation Loss: 0.1471
# Completed Epoch:  45 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0048 - Validation Loss: 0.2065
# Completed Epoch:  46 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0023 - Validation Loss: 0.1454
# Completed Epoch:  47 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0041 - Validation Loss: 0.1531
# Completed Epoch:  48 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0021 - Validation Loss: 0.1542
# Completed Epoch:  49 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0026 - Validation Loss: 0.1558
# Completed Epoch:  50 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0023 - Validation Loss: 0.1576
# Completed Epoch:  51 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1647
# Completed Epoch:  52 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0021 - Validation Loss: 0.1760
# Completed Epoch:  53 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0026 - Validation Loss: 0.1670
# Completed Epoch:  54 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.1653
# Completed Epoch:  55 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.1681
# Completed Epoch:  56 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0026 - Validation Loss: 0.1629
# Completed Epoch:  57 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0018 - Validation Loss: 0.1656
# Completed Epoch:  58 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2716
# Completed Epoch:  59 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1640
# Completed Epoch:  60 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0023 - Validation Loss: 0.1593
# Completed Epoch:  61 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1774
# Completed Epoch:  62 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1667
# Completed Epoch:  63 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.1664
# Completed Epoch:  64 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0016 - Validation Loss: 0.1729
# Completed Epoch:  65 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0024 - Validation Loss: 0.2586
# Completed Epoch:  66 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1891
# Completed Epoch:  67 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.1766
# Completed Epoch:  68 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.1724
# Completed Epoch:  69 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0028 - Validation Loss: 0.1766
# Completed Epoch:  70 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.1742
# Completed Epoch:  71 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0018 - Validation Loss: 0.1744
# Completed Epoch:  72 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0019 - Validation Loss: 0.1748
# Completed Epoch:  73 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1785
# Completed Epoch:  74 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.1797
# Completed Epoch:  75 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.1809
# Completed Epoch:  76 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1779
# Completed Epoch:  77 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0026 - Validation Loss: 0.1705
# Completed Epoch:  78 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.1704
# Completed Epoch:  79 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1754
# Completed Epoch:  80 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2957
# Completed Epoch:  81 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.1788
# Completed Epoch:  82 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1805
# Completed Epoch:  83 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0018 - Validation Loss: 0.1786
# Completed Epoch:  84 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1828
# Completed Epoch:  85 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0006 - Validation Loss: 0.1814
# Completed Epoch:  86 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1827
# Completed Epoch:  87 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0007 - Validation Loss: 0.1868
# Completed Epoch:  88 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0026 - Validation Loss: 0.1847
# Completed Epoch:  89 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0019 - Validation Loss: 0.1826
# Completed Epoch:  90 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1870
# Completed Epoch:  91 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2076
# Completed Epoch:  92 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1873
# Completed Epoch:  93 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1862
# Completed Epoch:  94 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1876
# Completed Epoch:  95 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1920
# Completed Epoch:  96 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1906
# Completed Epoch:  97 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.1972
# Completed Epoch:  98 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.2033
# Completed Epoch:  99 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1913
# Completed Epoch:  100 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1941
# Completed Epoch:  101 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1936
# Completed Epoch:  102 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0016 - Validation Loss: 0.1880
# Completed Epoch:  103 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1900
# Completed Epoch:  104 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2021
# Completed Epoch:  105 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1920
# Completed Epoch:  106 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1939
# Completed Epoch:  107 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1892
# Completed Epoch:  108 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1920
# Completed Epoch:  109 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.1958
# Completed Epoch:  110 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.3438
# Completed Epoch:  111 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1901
# Completed Epoch:  112 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.1912
# Completed Epoch:  113 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1920
# Completed Epoch:  114 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1988
# Completed Epoch:  115 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.1971
# Completed Epoch:  116 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1944
# Completed Epoch:  117 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2546
# Completed Epoch:  118 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.1994
# Completed Epoch:  119 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.1951
# Completed Epoch:  120 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.1997
# Completed Epoch:  121 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.1970
# Completed Epoch:  122 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1980
# Completed Epoch:  123 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.1979
# Completed Epoch:  124 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2027
# Completed Epoch:  125 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2489
# Completed Epoch:  126 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2025
# Completed Epoch:  127 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2034
# Completed Epoch:  128 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2044
# Completed Epoch:  129 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2065
# Completed Epoch:  130 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2017
# Completed Epoch:  131 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2026
# Completed Epoch:  132 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0007 - Validation Loss: 0.2056
# Completed Epoch:  133 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2051
# Completed Epoch:  134 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2059
# Completed Epoch:  135 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2080
# Completed Epoch:  136 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0016 - Validation Loss: 0.2096
# Completed Epoch:  137 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2105
# Completed Epoch:  138 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2114
# Completed Epoch:  139 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2095
# Completed Epoch:  140 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2080
# Completed Epoch:  141 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2062
# Completed Epoch:  142 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2034
# Completed Epoch:  143 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2126
# Completed Epoch:  144 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2098
# Completed Epoch:  145 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2080
# Completed Epoch:  146 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2070
# Completed Epoch:  147 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2050
# Completed Epoch:  148 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2107
# Completed Epoch:  149 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2088
# Completed Epoch:  150 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2073
# Completed Epoch:  151 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2094
# Completed Epoch:  152 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2093
# Completed Epoch:  153 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2096
# Completed Epoch:  154 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3092
# Completed Epoch:  155 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2101
# Completed Epoch:  156 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2096
# Completed Epoch:  157 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2830
# Completed Epoch:  158 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2073
# Completed Epoch:  159 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2110
# Completed Epoch:  160 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2109
# Completed Epoch:  161 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2099
# Completed Epoch:  162 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2509
# Completed Epoch:  163 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2098
# Completed Epoch:  164 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2099
# Completed Epoch:  165 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2340
# Completed Epoch:  166 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2120
# Completed Epoch:  167 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2095
# Completed Epoch:  168 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2123
# Completed Epoch:  169 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3691
# Completed Epoch:  170 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2368
# Completed Epoch:  171 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2167
# Completed Epoch:  172 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2114
# Completed Epoch:  173 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2129
# Completed Epoch:  174 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2127
# Completed Epoch:  175 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0017 - Validation Loss: 0.2098
# Completed Epoch:  176 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2144
# Completed Epoch:  177 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2168
# Completed Epoch:  178 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2179
# Completed Epoch:  179 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2171
# Completed Epoch:  180 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.2160
# Completed Epoch:  181 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.2127
# Completed Epoch:  182 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2115
# Completed Epoch:  183 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2104
# Completed Epoch:  184 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2093
# Completed Epoch:  185 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2152
# Completed Epoch:  186 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.2108
# Completed Epoch:  187 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2129
# Completed Epoch:  188 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2186
# Completed Epoch:  189 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2179
# Completed Epoch:  190 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2176
# Completed Epoch:  191 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2159
# Completed Epoch:  192 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2172
# Completed Epoch:  193 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.2173
# Completed Epoch:  194 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2139
# Completed Epoch:  195 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2167
# Completed Epoch:  196 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2140
# Completed Epoch:  197 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2154
# Completed Epoch:  198 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2135
# Completed Epoch:  199 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2153
# Completed Epoch:  200 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2180
# Completed Epoch:  201 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2156
# Completed Epoch:  202 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2653
# Completed Epoch:  203 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2177
# Completed Epoch:  204 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2189
# Completed Epoch:  205 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2169
# Completed Epoch:  206 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2176
# Completed Epoch:  207 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2177
# Completed Epoch:  208 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0014 - Validation Loss: 0.2132
# Completed Epoch:  209 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2150
# Completed Epoch:  210 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2162
# Completed Epoch:  211 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2173
# Completed Epoch:  212 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.3110
# Completed Epoch:  213 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2157
# Completed Epoch:  214 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2170
# Completed Epoch:  215 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2171
# Completed Epoch:  216 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2194
# Completed Epoch:  217 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2197
# Completed Epoch:  218 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2148
# Completed Epoch:  219 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2205
# Completed Epoch:  220 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2178
# Completed Epoch:  221 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2179
# Completed Epoch:  222 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2210
# Completed Epoch:  223 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2197
# Completed Epoch:  224 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2262
# Completed Epoch:  225 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2239
# Completed Epoch:  226 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2221
# Completed Epoch:  227 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2215
# Completed Epoch:  228 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2198
# Completed Epoch:  229 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3009
# Completed Epoch:  230 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2227
# Completed Epoch:  231 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3238
# Completed Epoch:  232 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2255
# Completed Epoch:  233 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2244
# Completed Epoch:  234 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2335
# Completed Epoch:  235 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.3127
# Completed Epoch:  236 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2237
# Completed Epoch:  237 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2243
# Completed Epoch:  238 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2407
# Completed Epoch:  239 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2244
# Completed Epoch:  240 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2231
# Completed Epoch:  241 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2273
# Completed Epoch:  242 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2273
# Completed Epoch:  243 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2272
# Completed Epoch:  244 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2259
# Completed Epoch:  245 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2270
# Completed Epoch:  246 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2289
# Completed Epoch:  247 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2286
# Completed Epoch:  248 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.3272
# Completed Epoch:  249 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2317
# Completed Epoch:  250 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2300
# Completed Epoch:  251 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0016 - Validation Loss: 0.2301
# Completed Epoch:  252 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2275
# Completed Epoch:  253 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2277
# Completed Epoch:  254 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2287
# Completed Epoch:  255 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2298
# Completed Epoch:  256 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2653
# Completed Epoch:  257 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2261
# Completed Epoch:  258 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3128
# Completed Epoch:  259 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2326
# Completed Epoch:  260 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2327
# Completed Epoch:  261 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2352
# Completed Epoch:  262 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2297
# Completed Epoch:  263 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2294
# Completed Epoch:  264 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2316
# Completed Epoch:  265 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2285
# Completed Epoch:  266 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2305
# Completed Epoch:  267 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0007 - Validation Loss: 0.3633
# Completed Epoch:  268 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2428
# Completed Epoch:  269 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2348
# Completed Epoch:  270 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2482
# Completed Epoch:  271 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2325
# Completed Epoch:  272 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2299
# Completed Epoch:  273 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2306
# Completed Epoch:  274 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2288
# Completed Epoch:  275 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2264
# Completed Epoch:  276 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2273
# Completed Epoch:  277 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2293
# Completed Epoch:  278 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2413
# Completed Epoch:  279 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2309
# Completed Epoch:  280 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2323
# Completed Epoch:  281 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2329
# Completed Epoch:  282 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2316
# Completed Epoch:  283 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3259
# Completed Epoch:  284 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2338
# Completed Epoch:  285 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2334
# Completed Epoch:  286 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2366
# Completed Epoch:  287 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2368
# Completed Epoch:  288 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2355
# Completed Epoch:  289 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2369
# Completed Epoch:  290 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2381
# Completed Epoch:  291 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0015 - Validation Loss: 0.2831
# Completed Epoch:  292 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2395
# Completed Epoch:  293 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2379
# Completed Epoch:  294 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2362
# Completed Epoch:  295 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2360
# Completed Epoch:  296 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2359
# Completed Epoch:  297 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2329
# Completed Epoch:  298 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2330
# Completed Epoch:  299 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2332
# Completed Epoch:  300 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2346
# Completed Epoch:  301 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2981
# Completed Epoch:  302 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2310
# Completed Epoch:  303 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2286
# Completed Epoch:  304 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2336
# Completed Epoch:  305 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2369
# Completed Epoch:  306 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2338
# Completed Epoch:  307 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2350
# Completed Epoch:  308 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2353
# Completed Epoch:  309 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2355
# Completed Epoch:  310 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2340
# Completed Epoch:  311 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2317
# Completed Epoch:  312 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2350
# Completed Epoch:  313 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2362
# Completed Epoch:  314 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2376
# Completed Epoch:  315 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2373
# Completed Epoch:  316 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2346
# Completed Epoch:  317 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2348
# Completed Epoch:  318 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2327
# Completed Epoch:  319 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2346
# Completed Epoch:  320 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2321
# Completed Epoch:  321 - Training Accuracy: 99 - Validation Accuracy: 95 - Training Loss: 0.0014 - Validation Loss: 0.2306
# Completed Epoch:  322 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2321
# Completed Epoch:  323 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2326
# Completed Epoch:  324 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2343
# Completed Epoch:  325 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2382
# Completed Epoch:  326 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2370
# Completed Epoch:  327 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2332
# Completed Epoch:  328 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2333
# Completed Epoch:  329 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2356
# Completed Epoch:  330 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2363
# Completed Epoch:  331 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2383
# Completed Epoch:  332 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3023
# Completed Epoch:  333 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2380
# Completed Epoch:  334 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2399
# Completed Epoch:  335 - Training Accuracy: 100 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2411
# Completed Epoch:  336 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2382
# Completed Epoch:  337 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2381
# Completed Epoch:  338 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2396
# Completed Epoch:  339 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2387
# Completed Epoch:  340 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2383
# Completed Epoch:  341 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3965
# Completed Epoch:  342 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2378
# Completed Epoch:  343 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2387
# Completed Epoch:  344 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3442
# Completed Epoch:  345 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2388
# Completed Epoch:  346 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2391
# Completed Epoch:  347 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2383
# Completed Epoch:  348 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2367
# Completed Epoch:  349 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2390
# Completed Epoch:  350 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2390
# Completed Epoch:  351 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.3048
# Completed Epoch:  352 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2394
# Completed Epoch:  353 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.4150
# Completed Epoch:  354 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2370
# Completed Epoch:  355 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2377
# Completed Epoch:  356 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2379
# Completed Epoch:  357 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2375
# Completed Epoch:  358 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2472
# Completed Epoch:  359 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2350
# Completed Epoch:  360 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2355
# Completed Epoch:  361 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2348
# Completed Epoch:  362 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2361
# Completed Epoch:  363 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3781
# Completed Epoch:  364 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2358
# Completed Epoch:  365 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2681
# Completed Epoch:  366 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2364
# Completed Epoch:  367 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2375
# Completed Epoch:  368 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2380
# Completed Epoch:  369 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2399
# Completed Epoch:  370 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2401
# Completed Epoch:  371 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2446
# Completed Epoch:  372 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2386
# Completed Epoch:  373 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.4168
# Completed Epoch:  374 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2391
# Completed Epoch:  375 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2393
# Completed Epoch:  376 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2406
# Completed Epoch:  377 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2425
# Completed Epoch:  378 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3429
# Completed Epoch:  379 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2430
# Completed Epoch:  380 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2447
# Completed Epoch:  381 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2404
# Completed Epoch:  382 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2731
# Completed Epoch:  383 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2377
# Completed Epoch:  384 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2367
# Completed Epoch:  385 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2395
# Completed Epoch:  386 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2813
# Completed Epoch:  387 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2412
# Completed Epoch:  388 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2423
# Completed Epoch:  389 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2419
# Completed Epoch:  390 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2436
# Completed Epoch:  391 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2424
# Completed Epoch:  392 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2429
# Completed Epoch:  393 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2455
# Completed Epoch:  394 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2452
# Completed Epoch:  395 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2621
# Completed Epoch:  396 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2467
# Completed Epoch:  397 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2461
# Completed Epoch:  398 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2442
# Completed Epoch:  399 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2426
# Completed Epoch:  400 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2425
# Completed Epoch:  401 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2422
# Completed Epoch:  402 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.2413
# Completed Epoch:  403 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2421
# Completed Epoch:  404 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2434
# Completed Epoch:  405 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2432
# Completed Epoch:  406 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2433
# Completed Epoch:  407 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2423
# Completed Epoch:  408 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3457
# Completed Epoch:  409 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2460
# Completed Epoch:  410 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2519
# Completed Epoch:  411 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2455
# Completed Epoch:  412 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2426
# Completed Epoch:  413 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2444
# Completed Epoch:  414 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2448
# Completed Epoch:  415 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2463
# Completed Epoch:  416 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2464
# Completed Epoch:  417 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2452
# Completed Epoch:  418 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2468
# Completed Epoch:  419 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3038
# Completed Epoch:  420 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2470
# Completed Epoch:  421 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2473
# Completed Epoch:  422 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2477
# Completed Epoch:  423 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0013 - Validation Loss: 0.2452
# Completed Epoch:  424 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2480
# Completed Epoch:  425 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2500
# Completed Epoch:  426 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2509
# Completed Epoch:  427 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2514
# Completed Epoch:  428 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0012 - Validation Loss: 0.3309
# Completed Epoch:  429 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2484
# Completed Epoch:  430 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2497
# Completed Epoch:  431 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2638
# Completed Epoch:  432 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2473
# Completed Epoch:  433 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2465
# Completed Epoch:  434 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2453
# Completed Epoch:  435 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2439
# Completed Epoch:  436 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2772
# Completed Epoch:  437 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2437
# Completed Epoch:  438 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2436
# Completed Epoch:  439 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2418
# Completed Epoch:  440 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2424
# Completed Epoch:  441 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2428
# Completed Epoch:  442 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2495
# Completed Epoch:  443 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2431
# Completed Epoch:  444 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2446
# Completed Epoch:  445 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2457
# Completed Epoch:  446 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2467
# Completed Epoch:  447 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3507
# Completed Epoch:  448 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2490
# Completed Epoch:  449 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2496
# Completed Epoch:  450 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2472
# Completed Epoch:  451 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2466
# Completed Epoch:  452 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2477
# Completed Epoch:  453 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.3145
# Completed Epoch:  454 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2476
# Completed Epoch:  455 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2469
# Completed Epoch:  456 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2473
# Completed Epoch:  457 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2537
# Completed Epoch:  458 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2471
# Completed Epoch:  459 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2479
# Completed Epoch:  460 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2478
# Completed Epoch:  461 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2472
# Completed Epoch:  462 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2470
# Completed Epoch:  463 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2472
# Completed Epoch:  464 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2482
# Completed Epoch:  465 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.3474
# Completed Epoch:  466 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2489
# Completed Epoch:  467 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0008 - Validation Loss: 0.2492
# Completed Epoch:  468 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2501
# Completed Epoch:  469 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2528
# Completed Epoch:  470 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2528
# Completed Epoch:  471 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2540
# Completed Epoch:  472 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2555
# Completed Epoch:  473 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2563
# Completed Epoch:  474 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3256
# Completed Epoch:  475 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2576
# Completed Epoch:  476 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3675
# Completed Epoch:  477 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2591
# Completed Epoch:  478 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.3044
# Completed Epoch:  479 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0011 - Validation Loss: 0.2582
# Completed Epoch:  480 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2582
# Completed Epoch:  481 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2579
# Completed Epoch:  482 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.3220
# Completed Epoch:  483 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2566
# Completed Epoch:  484 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0010 - Validation Loss: 0.2565
# Completed Epoch:  485 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2559
# Completed Epoch:  486 - Training Accuracy: 99 - Validation Accuracy: 96 - Training Loss: 0.0009 - Validation Loss: 0.2559

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
ax = ax.flatten()

ax[0].plot(train_loss_history, label="Train")
ax[0].plot(val_loss_history, label="Validation")
ax[0].title.set_text("Loss")
ax[0].legend()

ax[1].plot(train_accuracy_history, label="Train")
ax[1].plot(val_accuracy_history, label="Validation")
ax[1].title.set_text("Accuracy Score")
ax[1].legend()

plt.show()

# %%
print(classification_report(test.targets, all_preds))

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(confusion_matrix(test.targets, all_preds), cmap="Blues", annot=True, fmt="d")
plt.title("Confusion Matrix", size=15)
plt.show()

# %% [markdown]
# ## Manual Testing

# %% [markdown]
# It is always a good practice to test the model manually and try to understand what is going on in prediction. Let's choose a single sample out of test set and make the model predict that single image.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 6))
ax = ax.flatten()

ax[0].imshow(data[-1][0].permute(1, 2, 0))
ax[0].title.set_text(f"{labels_for_viz[data[-1][1]]} (Before Preprocessing)")

ax[1].imshow(test[-1][0].permute(1, 2, 0))
ax[1].title.set_text(f"{labels_for_viz[test[-1][1]]} (After Preprocessing)")
plt.show()

# %% [markdown]
# In the code above, I fetched the last sample of test set and its class is "Healthy". Now, it is time to find out what the probabilities are for each class.

# %%
single_prediction = model.forward((test[-1][0]).to(device).unsqueeze(0))
single_prediction

# %% [markdown]
# Then index of the class with highest probability should be taken for printing the corresponding label.

# %%
single_prediction = int(torch.max(single_prediction, 1)[1])
print("Predicted Class:", labels_for_viz[single_prediction])
